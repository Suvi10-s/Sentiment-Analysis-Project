# %%
import pandas as pd
import contractions
import emoji
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB
import joblib
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                                           text     label
# 0     OMG!!! I love this sooo much 😍🔥 #awesome  positive
# 1     Worst product ever!!! broke in 2 days 😡💔  negative
# 2                   meh it's okay i guess 🤷‍♂️   neutral
# 3   @shop totally loved it!! will buy again 😍😍  positive
# 4           this is baaad quality man 😤 #waste  negative
# 5                 not good not bad just fine 🙂   neutral
# 6            Soooo happy with this purchase 😄💖  positive
# 7     terrible service!!! never coming back 😠😠  negative
# 8            it works... nothing special tho 🤨   neutral
# 9            best thing i bought this year 🔥🔥🔥  positive
# 10                     do NOT buy this crap 😡❌  negative
# 11                   it's okay for daily use 👍   neutral
# 12               i really really love this 😍😍😍  positive
# 13                 worst experience everrrr 😤💔  negative
# 14                      hmm its fine i guess 😐   neutral
# ...

# %%
df["text"] = df["text"].str.lower()
df.head()
# Out:
#                                          text     label
# 0    omg!!! i love this sooo much 😍🔥 #awesome  positive
# 1    worst product ever!!! broke in 2 days 😡💔  negative
# 2                  meh it's okay i guess 🤷‍♂️   neutral
# 3  @shop totally loved it!! will buy again 😍😍  positive
# 4          this is baaad quality man 😤 #waste  negative

# %%
df["text"]=df["text"].str.replace(r"\S+@\S+"," ",regex=True)
df.head()
# Out:
#                                          text     label
# 0    omg!!! i love this sooo much 😍🔥 #awesome  positive
# 1    worst product ever!!! broke in 2 days 😡💔  negative
# 2                  meh it's okay i guess 🤷‍♂️   neutral
# 3  @shop totally loved it!! will buy again 😍😍  positive
# 4          this is baaad quality man 😤 #waste  negative

# %%
df["text"] = df["text"].str.replace(r"@\S+"," ",regex = True)
df.head()
# Out:
#                                        text     label
# 0  omg!!! i love this sooo much 😍🔥 #awesome  positive
# 1  worst product ever!!! broke in 2 days 😡💔  negative
# 2                meh it's okay i guess 🤷‍♂️   neutral
# 3      totally loved it!! will buy again 😍😍  positive
# 4        this is baaad quality man 😤 #waste  negative

# %%
df["text"] = df["text"].str.replace(r"https?://\S+|www\.\S+"," ",regex = True)
df.head()
# Out:
#                                        text     label
# 0  omg!!! i love this sooo much 😍🔥 #awesome  positive
# 1  worst product ever!!! broke in 2 days 😡💔  negative
# 2                meh it's okay i guess 🤷‍♂️   neutral
# 3      totally loved it!! will buy again 😍😍  positive
# 4        this is baaad quality man 😤 #waste  negative

# %%
df["text"] = df["text"].str.replace(r"#"," ",regex = True)
df.head()
# Out:
#                                        text     label
# 0  omg!!! i love this sooo much 😍🔥  awesome  positive
# 1  worst product ever!!! broke in 2 days 😡💔  negative
# 2                meh it's okay i guess 🤷‍♂️   neutral
# 3      totally loved it!! will buy again 😍😍  positive
# 4        this is baaad quality man 😤  waste  negative

# %%
df["text"] = df["text"].apply(lambda x:contractions.fix(x))
df.head(22)
# Out:
#                                         text     label
# 0   omg!!! i love this sooo much 😍🔥  awesome  positive
# 1   worst product ever!!! broke in 2 days 😡💔  negative
# 2                meh it is okay i guess 🤷‍♂️   neutral
# 3       totally loved it!! will buy again 😍😍  positive
# 4         this is baaad quality man 😤  waste  negative
# 5               not good not bad just fine 🙂   neutral
# 6          soooo happy with this purchase 😄💖  positive
# 7   terrible service!!! never coming back 😠😠  negative
# 8       it works... nothing special though 🤨   neutral
# 9          best thing i bought this year 🔥🔥🔥  positive
# 10                   do not buy this crap 😡❌  negative
# 11                it is okay for daily use 👍   neutral
# 12             i really really love this 😍😍😍  positive
# 13               worst experience everrrr 😤💔  negative
# 14                    hmm its fine i guess 😐   neutral
# 15                       this made my day 😄✨  positive
# ...

# %%
df["text"]=df["text"].str.replace(r"(.)\1{2,}",r"\1\1",regex=True)
df.head(22)
# Out:
#                                        text     label
# 0    omg!! i love this soo much 😍🔥  awesome  positive
# 1   worst product ever!! broke in 2 days 😡💔  negative
# 2               meh it is okay i guess 🤷‍♂️   neutral
# 3      totally loved it!! will buy again 😍😍  positive
# 4         this is baad quality man 😤  waste  negative
# 5              not good not bad just fine 🙂   neutral
# 6           soo happy with this purchase 😄💖  positive
# 7   terrible service!! never coming back 😠😠  negative
# 8       it works.. nothing special though 🤨   neutral
# 9          best thing i bought this year 🔥🔥  positive
# 10                  do not buy this crap 😡❌  negative
# 11               it is okay for daily use 👍   neutral
# 12             i really really love this 😍😍  positive
# 13                worst experience everr 😤💔  negative
# 14                   hmm its fine i guess 😐   neutral
# 15                      this made my day 😄✨  positive
# ...

# %%
def emoji_to_sentiment(text):
    if not type(text)==str:
        return text
    text = emoji.demojize(text)
    happy_words = [
    "smi","grin","laugh","joy","happy","love","heart",
    "kiss","hug","blush","relief","satisfy",
    "star","sparkle","fire","glow",
    "cool","sunglass",
    "thumb","clap","ok","victory",
    "party","confetti","tada",
    "beam","cheer","excite",
    "amaze","fantastic","good",
    "hundred","muscle","rocket","rainbow"
]
    sad_words = [
    "sad","cry","sob","angry","rage",
    "frown","disappoint","break","pain","hurt",
    "fear","scare","terror","scream",
    "weary","tire","sleep","pensive","confuse",
    "grim","awkward","frustrate","annoy",
    "vomit","sick","nausea",
    "anguish","depress","miserable","upset",
    "bad","worst","steam","without","unamused",
]
    neutral_words = [
    "ok","okay","fine","normal","average",
    "neutral","meh",
    "think","consider",
    "shrug","unsure","indifferent","with",
    "blank","calm","straight"
]
    emoji_word = re.findall(r":\S+:",text)
    for emojis in emoji_word:
        exact_words = re.sub(r"[:_]+"," ",emojis)
        for word in happy_words:
            if word in exact_words:
                text = text.replace(emojis," happy ")
                break
        for word in sad_words:
            if word in exact_words:
                text = text.replace(emojis," sad ")
                break
        for word in neutral_words:
            if word in exact_words:
                text = text.replace(emojis," neutral ")
                break
    return text

# %%
df["text"]=df["text"].apply(lambda x:emoji_to_sentiment(x))
df
# Out:
#                                             text     label
# 0    omg!! i love this soo much  happy   awesome  positive
# 1   worst product ever!! broke in 2 days  happy   negative
# 2               meh it is okay i guess  neutral    neutral
# 3      totally loved it!! will buy again  happy   positive
# 4          this is baad quality man  sad   waste  negative
# 5             not good not bad just fine  happy    neutral
# 6           soo happy with this purchase  happy   positive
# 7     terrible service!! never coming back  sad   negative
# 8    it works.. nothing special though  neutral    neutral
# 9          best thing i bought this year  happy   positive
# 10                    do not buy this crap  sad   negative
# 11              it is okay for daily use  happy    neutral
# 12             i really really love this  happy   positive
# 13                worst experience everr  happy   negative
# 14                hmm its fine i guess  neutral    neutral
# ...

# %%
df["text"] = df["text"].str.replace(r"[^a-zA-Z]"," ",regex=True)
df.head()
# Out:
#                                            text     label
# 0   omg   i love this soo much  happy   awesome  positive
# 1  worst product ever   broke in   days  happy   negative
# 2              meh it is okay i guess  neutral    neutral
# 3     totally loved it   will buy again  happy   positive
# 4         this is baad quality man  sad   waste  negative

# %%
df["text"] = df["text"].str.replace(r"\s+"," ",regex = True)
df
# Out:
#                                         text     label
# 0     omg i love this soo much happy awesome  positive
# 1    worst product ever broke in days happy   negative
# 2            meh it is okay i guess neutral    neutral
# 3     totally loved it will buy again happy   positive
# 4         this is baad quality man sad waste  negative
# 5          not good not bad just fine happy    neutral
# 6        soo happy with this purchase happy   positive
# 7    terrible service never coming back sad   negative
# 8   it works nothing special though neutral    neutral
# 9       best thing i bought this year happy   positive
# 10                 do not buy this crap sad   negative
# 11           it is okay for daily use happy    neutral
# 12          i really really love this happy   positive
# 13             worst experience everr happy   negative
# 14             hmm its fine i guess neutral    neutral
# 15                   this made my day happy   positive
# ...

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2))

# %%
df_matrix = vectorizer.fit_transform(df["text"])
df_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 464 stored elements and shape (50, 296)>

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['about' 'about this' 'absolutely' 'absolutely amazingg' 'acceptable'
#  'acceptable guess' 'after' 'after using' 'again' 'again happy' 'am'
#  'am so' 'amazingg' 'amazingg happy' 'and' 'and frustrating' 'average'
#  'average product' 'awesome' 'awesome after' 'awful' 'awful experience'
#  'baad' 'baad quality' 'back' 'back sad' 'bad' 'bad just' 'bad neutral'
#  'bad packaging' 'bad sad' 'best' 'best thing' 'bought' 'bought sad'
#  'bought this' 'broke' 'broke in' 'broke quickly' 'buy' 'buy again'
#  'buy this' 'cheap' 'cheap quality' 'coming' 'coming back' 'completely'
#  'completely happy' 'completely useless' 'cool' 'cool happy' 'crap'
#  'crap sad' 'daily' 'daily use' 'day' 'day happy' 'days' 'days happy'
#  'decent' 'decent not' 'delivery' 'delivery happy' 'disappointing'
#  'disappointing experience' 'do' 'do not' 'ever' 'ever broke' 'everr'
#  'everr happy' 'excellent' 'excellent quality' 'experience'
#  'experience do' 'experience everr' 'experience sad' 'fantastic'
# ...

# %%
tf_matrix = pd.DataFrame(df_matrix.toarray(),columns=vectorizer.get_feature_names_out())
tf_matrix
# Out:
#        about  about this  absolutely  absolutely amazingg  acceptable  \
# 0   0.000000    0.000000    0.000000             0.000000    0.000000
# 1   0.000000    0.000000    0.000000             0.000000    0.000000
# 2   0.000000    0.000000    0.000000             0.000000    0.000000
# 3   0.000000    0.000000    0.000000             0.000000    0.000000
# 4   0.000000    0.000000    0.000000             0.000000    0.000000
# 5   0.000000    0.000000    0.000000             0.000000    0.000000
# 6   0.000000    0.000000    0.000000             0.000000    0.000000
# 7   0.000000    0.000000    0.000000             0.000000    0.000000
# 8   0.000000    0.000000    0.000000             0.000000    0.000000
# 9   0.000000    0.000000    0.000000             0.000000    0.000000
# 10  0.000000    0.000000    0.000000             0.000000    0.000000
# 11  0.000000    0.000000    0.000000             0.000000    0.000000
# ...

# %%
le = LabelEncoder()
df["label"]=le.fit_transform(df["label"])
x = df_matrix
y = df["label"]
df
# Out:
#                                         text  label
# 0     omg i love this soo much happy awesome      2
# 1    worst product ever broke in days happy       0
# 2            meh it is okay i guess neutral       1
# 3     totally loved it will buy again happy       2
# 4         this is baad quality man sad waste      0
# 5          not good not bad just fine happy       1
# 6        soo happy with this purchase happy       2
# 7    terrible service never coming back sad       0
# 8   it works nothing special though neutral       1
# 9       best thing i bought this year happy       2
# 10                 do not buy this crap sad       0
# 11           it is okay for daily use happy       1
# 12          i really really love this happy       2
# 13             worst experience everr happy       0
# 14             hmm its fine i guess neutral       1
# 15                   this made my day happy       2
# 16                 i hate this soo much sad       0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, stratify=y)

# %%
model = LogisticRegression(class_weight="balanced")

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 2, 0, 2, 2, 0, 1, 0, 0, 1])

# %%
accuracy = accuracy_score(y_pred,y_test)
print("accuracy:", accuracy)
# Out:
# accuracy: 0.9

# %%
report = classification_report(y_pred,y_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         4
#            1       1.00      1.00      1.00         3
#            2       0.75      1.00      0.86         3
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.92      0.90        10
# weighted avg       0.93      0.90      0.90        10

# %%
confusion_score = confusion_matrix(y_pred,y_test)
print(confusion_score)
# Out:
# [[3 0 1]
#  [0 3 0]
#  [0 0 3]]

# %%
accuracy_mark=accuracy_score(y_pred,y_test)
print(accuracy_mark)
# Out:
# 0.9

# %%
classification_mark=classification_report(y_pred,y_test)
print(classification_mark)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         4
#            1       1.00      1.00      1.00         3
#            2       0.75      1.00      0.86         3
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.92      0.90        10
# weighted avg       0.93      0.90      0.90        10

# %%
confusion_mark=confusion_matrix(y_pred,y_test)
print(confusion_mark)
# Out:
# [[3 0 1]
#  [0 3 0]
#  [0 0 3]]

# %%
score = cross_val_score(model,x,y,cv=5)
print(" accuracy :", score)
print(" mean_accuracy :",score.mean())
# Out:
#  accuracy : [1.  0.8 1.  0.9 0.8]
#  mean_accuracy : 0.9

# %%
model_nb = MultinomialNB()

# %%
model_nb.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred_=model_nb.predict(x_test)

# %%
accuracy_score_nb=accuracy_score(y_pred_,y_test)
accuracy_score_nb
# Out:
# 0.9

# %%
report_nb = classification_report(y_pred_,y_test)
print(report_nb)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         4
#            1       1.00      1.00      1.00         3
#            2       0.75      1.00      0.86         3
#
#     accuracy                           0.90        10
#    macro avg       0.92      0.92      0.90        10
# weighted avg       0.93      0.90      0.90        10

# %%
confusion_matrix_nb = confusion_matrix(y_pred_,y_test)
print(confusion_matrix_nb)
# Out:
# [[3 0 1]
#  [0 3 0]
#  [0 0 3]]

# %%
score_nb = cross_val_score(model_nb,x,y,cv=5)
print("score :", score_nb)
print("mean accuracy:",score_nb.mean())
# Out:
# score : [0.9 0.9 1.  0.9 0.8]
# mean accuracy: 0.9

# %%
joblib.dump(model_nb,"sentiment analysis nb.pkl")
# Out:
# ['sentiment analysis nb.pkl']

# %%
joblib.dump(model,"sentiment analysis logistic.pkl")
# Out:
# ['sentiment analysis logistic.pkl']

# %%
joblib.dump(vectorizer,"vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
